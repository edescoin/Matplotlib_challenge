# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

city_data_df = pd.read_csv(r'C:\Users\ENOCK DESCOPIN\Desktop\RICHRIC201907DATA3\RICHRIC201907DATA3\05-Matplotlib\Homework\Pyber\data\city_data.csv')
ride_data_df = pd.read_csv(r'C:\Users\ENOCK DESCOPIN\Desktop\RICHRIC201907DATA3\RICHRIC201907DATA3\05-Matplotlib\Homework\Pyber\data\ride_data.csv')

# %%
# merge Data files together
merged_df = city_data_df.merge(ride_data_df, on='city', how='outer')

# Preview of the Data files
merged_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
#give a new value to it
ridedata_df_official = ride_data

# %%
city_data_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
#merge the dataset on city 
mergeddata_df = pd.merge(ride_data_df,city_data_df, how = 'outer', on='city')

# %%
mergeddata_df.loc[mergeddata_df['city']=='Spencertown']
# Out:
# Empty DataFrame
# Columns: [city, date, fare, ride_id, driver_count, type]
# Index: []

# %%
mergeddata_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1     Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2     Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3     Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4     Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
# ...                  ...                  ...    ...            ...
# 2370        West Heather  2018-04-18 19:33:12  46.60  3671003215967
# 2371        West Heather  2018-03-02 21:04:10  20.99  5766454453070
# 2372        West Heather  2018-03-06 20:06:51  48.11  2570548892682
# 2373        West Heather  2018-02-02 06:28:04  53.07  2462950442268
# 2374        West Heather  2018-05-07 19:22:15  44.94  4256853490277
#
#       driver_count   type
# 0                5  Urban
# 1                5  Urban
# 2                5  Urban
# 3                5  Urban
# ...

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
#bubble plot
#Average Fare ($) Per City
#Total Number of Rides Per City
#Total Number of Drivers Per City
#City Type (Urban, Suburban, Rural)"

bubble_plot_df = mergeddata_df[['city','fare','driver_count', 'type']]

# %%
average_ride = round(bubble_plot_df.groupby('city')['fare'].mean(),2)
total_number_rides = bubble_plot_df.groupby('city')['city'].count()
total_number_drivers = bubble_plot_df.groupby('city')['driver_count'].count()

# %%
total_number_drivers
# Out:
# city
# Amandaburgh         18
# Barajasview         22
# Barronchester       16
# Bethanyland         18
# Bradshawfurt        10
#                     ..
# West Robert         31
# West Samuelburgh    25
# Williamsonville     14
# Williamsstad        23
# Williamsview        20
# Name: driver_count, Length: 120, dtype: int64

# %%
city_type = bubble_plot_df.groupby('type').nunique()

# %%
city_type = city_type[['city']]
city_type
# Out:
#           city
# type
# Rural       18
# Suburban    36
# Urban       66

# %%
#%  of total rides
type_group = bubble_plot_df.groupby('type')
count_groupbyrides = type_group['type'].count()
count_groupbyrides
colors = ['orange','lightblue','red']
explode = (0,0,.2)
piechart_percentage_totalrides = count_groupbyrides.plot(kind = 'pie', colors=colors, figsize=(9,9), autopct='%1.1f%%',
                                                         explode =explode, fontsize= 14)

piechart_percentage_totalrides.set_title("% of Total Rides by City Types", fontsize = 20)
plt.show()

# %% [markdown]
# ## Total Fares by City Type
